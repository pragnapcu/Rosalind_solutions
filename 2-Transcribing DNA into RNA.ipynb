# %% [markdown]
# ## Transcribing DNA into RNA

# %% [markdown]
# ### Given: A DNA string t having length at most 1000 nt.
#
# ### Return: The transcribed RNA string of t.

# %%
t = "..."

t_transcribe = t.replace('T', 'U')
print(t_transcribe)
# Out:
# ...
